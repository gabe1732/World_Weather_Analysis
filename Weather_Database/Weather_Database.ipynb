# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time 
from datetime import datetime
import requests
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b53842aeea1db5498aa5731b1e10c1c

# %%
# create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)

lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

lat_lngs = zip(lats, lngs)

lat_lngs

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in lat_lngs:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        #for testing purpose REMOVE!!!!!!!
        #if len(cities) < 10:
        cities.append(city)     
        
    
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 773

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Datat Retrieval   ")
print("............................")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list. 
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, repord, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})
                          

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Datat Retrieval
# ............................
# Processing Record 1 of Set 1 | saint-philippe
# Processing Record 2 of Set 1 | aswan
# Processing Record 3 of Set 1 | durres
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | kodiak
# Processing Record 6 of Set 1 | burnie
# Processing Record 7 of Set 1 | beterou
# Processing Record 8 of Set 1 | san patricio
# Processing Record 9 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | cabra
# Processing Record 12 of Set 1 | vallenar
# Processing Record 13 of Set 1 | brae
# Processing Record 14 of Set 1 | saraland
# Processing Record 15 of Set 1 | cape town
# Processing Record 16 of Set 1 | mayo
# Processing Record 17 of Set 1 | hithadhoo
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | fairbanks
# Processing Record 20 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 1 | thompson
# Processing Record 22 of Set 1 | souillac
# Processing Record 23 of Set 1 | bredasdorp
# Processing Record 24 of Set 1 | chifeng
# Processing Record 25 of Set 1 | ntungamo
# Processing Record 26 of Set 1 | hamilton
# Processing Record 27 of Set 1 | castro
# Processing Record 28 of Set 1 | gardan diwal
# City not found. Skipping...
# Processing Record 29 of Set 1 | hermanus
# Processing Record 30 of Set 1 | cabo san lucas
# Processing Record 31 of Set 1 | geraldton
# Processing Record 32 of Set 1 | mar del plata
# Processing Record 33 of Set 1 | ostrovnoy
# Processing Record 34 of Set 1 | ponta do sol
# Processing Record 35 of Set 1 | rikitea
# Processing Record 36 of Set 1 | butaritari
# Processing Record 37 of Set 1 | qaanaaq
# Processing Record 38 of Set 1 | aklavik
# Processing Record 39 of Set 1 | saint george
# Processing Record 40 of Set 1 | puerto ayora
# Processing Record 41 of Set 1 | ushuaia
# Processing Record 42 of Set 1 | hobart
# Processing Record 43 of Set 1 | tuktoyaktuk
# Processing Record 44 of Set 1 | manavalakurichi
# Processing Record 45 of Set 1 | ovalle
# Processing Record 46 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 1 | soller
# Processing Record 48 of Set 1 | cherskiy
# Processing Record 49 of Set 1 | punta arenas
# Processing Record 50 of Set 1 | nikolskoye
# Processing Record 1 of Set 2 | mahajanga
# Processing Record 2 of Set 2 | touros
# Processing Record 3 of Set 2 | karoi
# Processing Record 4 of Set 2 | welahan
# Processing Record 5 of Set 2 | bridlington
# Processing Record 6 of Set 2 | mandan
# Processing Record 7 of Set 2 | dikson
# Processing Record 8 of Set 2 | kaeo
# Processing Record 9 of Set 2 | coos bay
# Processing Record 10 of Set 2 | upata
# Processing Record 11 of Set 2 | sur
# Processing Record 12 of Set 2 | jamestown
# Processing Record 13 of Set 2 | sitka
# Processing Record 14 of Set 2 | vestmannaeyjar
# Processing Record 15 of Set 2 | chumikan
# Processing Record 16 of Set 2 | olafsvik
# Processing Record 17 of Set 2 | upernavik
# Processing Record 18 of Set 2 | luwuk
# Processing Record 19 of Set 2 | hvammstangi
# City not found. Skipping...
# Processing Record 20 of Set 2 | horsham
# Processing Record 21 of Set 2 | airai
# Processing Record 22 of Set 2 | wilmington
# Processing Record 23 of Set 2 | bluff
# Processing Record 24 of Set 2 | choix
# Processing Record 25 of Set 2 | kusk
# City not found. Skipping...
# Processing Record 26 of Set 2 | vaini
# Processing Record 27 of Set 2 | kapaa
# Processing Record 28 of Set 2 | blenheim
# Processing Record 29 of Set 2 | koumac
# Processing Record 30 of Set 2 | vao
# Processing Record 31 of Set 2 | arraial do cabo
# Processing Record 32 of Set 2 | mahebourg
# Processing Record 33 of Set 2 | broome
# Processing Record 34 of Set 2 | barrow
# Processing Record 35 of Set 2 | new norfolk
# Processing Record 36 of Set 2 | severo-kurilsk
# Processing Record 37 of Set 2 | belle fourche
# Processing Record 38 of Set 2 | port hardy
# Processing Record 39 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 2 | kushima
# Processing Record 41 of Set 2 | chuy
# Processing Record 42 of Set 2 | yellowknife
# Processing Record 43 of Set 2 | guerrero negro
# Processing Record 44 of Set 2 | saskylakh
# Processing Record 45 of Set 2 | riverton
# Processing Record 46 of Set 2 | marawi
# Processing Record 47 of Set 2 | hilo
# Processing Record 48 of Set 2 | oranjemund
# Processing Record 49 of Set 2 | garissa
# Processing Record 50 of Set 2 | sioux lookout
# Processing Record 1 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 3 | oudtshoorn
# Processing Record 3 of Set 3 | arandis
# Processing Record 4 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 5 of Set 3 | correntina
# Processing Record 6 of Set 3 | saint-augustin
# Processing Record 7 of Set 3 | karratha
# Processing Record 8 of Set 3 | nyuksenitsa
# Processing Record 9 of Set 3 | marystown
# Processing Record 10 of Set 3 | bambous virieux
# Processing Record 11 of Set 3 | lavrentiya
# Processing Record 12 of Set 3 | bezhetsk
# Processing Record 13 of Set 3 | georgetown
# Processing Record 14 of Set 3 | san cristobal
# Processing Record 15 of Set 3 | bacuit
# City not found. Skipping...
# Processing Record 16 of Set 3 | hasaki
# Processing Record 17 of Set 3 | bengkulu
# Processing Record 18 of Set 3 | kaitangata
# Processing Record 19 of Set 3 | mayumba
# Processing Record 20 of Set 3 | carnarvon
# Processing Record 21 of Set 3 | kembolcha
# Processing Record 22 of Set 3 | victoria
# Processing Record 23 of Set 3 | zapolyarnyy
# Processing Record 24 of Set 3 | visby
# Processing Record 25 of Set 3 | neryungri
# Processing Record 26 of Set 3 | usakos
# Processing Record 27 of Set 3 | port alfred
# Processing Record 28 of Set 3 | ullapool
# Processing Record 29 of Set 3 | chokurdakh
# Processing Record 30 of Set 3 | sarahan
# Processing Record 31 of Set 3 | mehamn
# Processing Record 32 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 3 | povenets
# Processing Record 34 of Set 3 | plettenberg bay
# Processing Record 35 of Set 3 | beringovskiy
# Processing Record 36 of Set 3 | faanui
# Processing Record 37 of Set 3 | naze
# Processing Record 38 of Set 3 | oistins
# Processing Record 39 of Set 3 | atuona
# Processing Record 40 of Set 3 | coquimbo
# Processing Record 41 of Set 3 | kavieng
# Processing Record 42 of Set 3 | minab
# Processing Record 43 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 3 | ciudad bolivar
# Processing Record 45 of Set 3 | necochea
# Processing Record 46 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 3 | khatanga
# Processing Record 49 of Set 3 | poum
# Processing Record 50 of Set 3 | shizunai
# Processing Record 1 of Set 4 | pevek
# Processing Record 2 of Set 4 | xiangdong
# City not found. Skipping...
# Processing Record 3 of Set 4 | avarua
# Processing Record 4 of Set 4 | bosaso
# Processing Record 5 of Set 4 | zavolzhsk
# Processing Record 6 of Set 4 | vila velha
# Processing Record 7 of Set 4 | manokwari
# Processing Record 8 of Set 4 | kruisfontein
# Processing Record 9 of Set 4 | veraval
# Processing Record 10 of Set 4 | khash
# Processing Record 11 of Set 4 | patacamaya
# Processing Record 12 of Set 4 | benghazi
# Processing Record 13 of Set 4 | popondetta
# Processing Record 14 of Set 4 | pathein
# Processing Record 15 of Set 4 | bandarbeyla
# Processing Record 16 of Set 4 | xinyang
# Processing Record 17 of Set 4 | siguiri
# Processing Record 18 of Set 4 | laguna
# Processing Record 19 of Set 4 | gasa
# Processing Record 20 of Set 4 | motygino
# Processing Record 21 of Set 4 | pisco
# Processing Record 22 of Set 4 | abong mbang
# Processing Record 23 of Set 4 | kurilsk
# Processing Record 24 of Set 4 | namatanai
# Processing Record 25 of Set 4 | cabedelo
# Processing Record 26 of Set 4 | torbay
# Processing Record 27 of Set 4 | luderitz
# Processing Record 28 of Set 4 | katsuura
# Processing Record 29 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 30 of Set 4 | kunashak
# Processing Record 31 of Set 4 | lebu
# Processing Record 32 of Set 4 | toro
# Processing Record 33 of Set 4 | norman wells
# Processing Record 34 of Set 4 | ilhabela
# Processing Record 35 of Set 4 | clyde river
# Processing Record 36 of Set 4 | talara
# Processing Record 37 of Set 4 | gorontalo
# Processing Record 38 of Set 4 | bjornevatn
# Processing Record 39 of Set 4 | bairiki
# Processing Record 40 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 41 of Set 4 | aykhal
# Processing Record 42 of Set 4 | christchurch
# Processing Record 43 of Set 4 | haverfordwest
# Processing Record 44 of Set 4 | phalaborwa
# Processing Record 45 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 4 | fairmont
# Processing Record 47 of Set 4 | dingle
# Processing Record 48 of Set 4 | chunar
# Processing Record 49 of Set 4 | tasiilaq
# Processing Record 50 of Set 4 | fomboni
# Processing Record 1 of Set 5 | mantua
# Processing Record 2 of Set 5 | denpasar
# Processing Record 3 of Set 5 | fortuna
# Processing Record 4 of Set 5 | paducah
# Processing Record 5 of Set 5 | wanaka
# Processing Record 6 of Set 5 | ahumada
# City not found. Skipping...
# Processing Record 7 of Set 5 | parana
# Processing Record 8 of Set 5 | ketchikan
# Processing Record 9 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 10 of Set 5 | ribeira grande
# Processing Record 11 of Set 5 | havoysund
# Processing Record 12 of Set 5 | miraflores
# Processing Record 13 of Set 5 | bandar-e lengeh
# Processing Record 14 of Set 5 | westport
# Processing Record 15 of Set 5 | miri
# Processing Record 16 of Set 5 | sinnamary
# Processing Record 17 of Set 5 | dunedin
# Processing Record 18 of Set 5 | ravar
# Processing Record 19 of Set 5 | gladstone
# Processing Record 20 of Set 5 | djibo
# Processing Record 21 of Set 5 | mataram
# Processing Record 22 of Set 5 | itarema
# Processing Record 23 of Set 5 | codrington
# Processing Record 24 of Set 5 | nizhniy odes
# Processing Record 25 of Set 5 | duz
# City not found. Skipping...
# Processing Record 26 of Set 5 | bay roberts
# Processing Record 27 of Set 5 | kailua
# Processing Record 28 of Set 5 | kapit
# Processing Record 29 of Set 5 | gao
# Processing Record 30 of Set 5 | maceio
# Processing Record 31 of Set 5 | fort stewart
# Processing Record 32 of Set 5 | tiksi
# Processing Record 33 of Set 5 | cape canaveral
# Processing Record 34 of Set 5 | cidreira
# Processing Record 35 of Set 5 | florianopolis
# Processing Record 36 of Set 5 | tlahualilo
# City not found. Skipping...
# Processing Record 37 of Set 5 | kavaratti
# Processing Record 38 of Set 5 | darhan
# Processing Record 39 of Set 5 | xuanhua
# Processing Record 40 of Set 5 | tosya
# Processing Record 41 of Set 5 | port macquarie
# Processing Record 42 of Set 5 | padang
# Processing Record 43 of Set 5 | ferrol
# Processing Record 44 of Set 5 | prince rupert
# Processing Record 45 of Set 5 | moranbah
# Processing Record 46 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 5 | xiaoweizhai
# Processing Record 48 of Set 5 | candelaria
# Processing Record 49 of Set 5 | yulara
# Processing Record 50 of Set 5 | port blair
# Processing Record 1 of Set 6 | hammerfest
# Processing Record 2 of Set 6 | kiunga
# Processing Record 3 of Set 6 | taoudenni
# Processing Record 4 of Set 6 | boyabat
# Processing Record 5 of Set 6 | kewanee
# Processing Record 6 of Set 6 | kongolo
# Processing Record 7 of Set 6 | navalmoral de la mata
# Processing Record 8 of Set 6 | semporna
# Processing Record 9 of Set 6 | sechelt
# Processing Record 10 of Set 6 | moron
# Processing Record 11 of Set 6 | skagastrond
# City not found. Skipping...
# Processing Record 12 of Set 6 | pilar
# Processing Record 13 of Set 6 | latung
# Processing Record 14 of Set 6 | matay
# Processing Record 15 of Set 6 | pacific grove
# Processing Record 16 of Set 6 | narsaq
# Processing Record 17 of Set 6 | evensk
# Processing Record 18 of Set 6 | adeje
# Processing Record 19 of Set 6 | leningradskiy
# Processing Record 20 of Set 6 | lodja
# Processing Record 21 of Set 6 | mbeya
# Processing Record 22 of Set 6 | basoko
# Processing Record 23 of Set 6 | krasnoselkup
# Processing Record 24 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 6 | erdenet
# Processing Record 26 of Set 6 | bardiyah
# Processing Record 27 of Set 6 | juegang
# Processing Record 28 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 29 of Set 6 | rudnaya pristan
# Processing Record 30 of Set 6 | coihaique
# Processing Record 31 of Set 6 | yeppoon
# Processing Record 32 of Set 6 | atambua
# Processing Record 33 of Set 6 | valleyview
# Processing Record 34 of Set 6 | shelburne
# Processing Record 35 of Set 6 | asau
# Processing Record 36 of Set 6 | bathsheba
# Processing Record 37 of Set 6 | mandalgovi
# Processing Record 38 of Set 6 | deputatskiy
# Processing Record 39 of Set 6 | shingu
# Processing Record 40 of Set 6 | arman
# Processing Record 41 of Set 6 | vardo
# Processing Record 42 of Set 6 | sadovoye
# Processing Record 43 of Set 6 | kizner
# Processing Record 44 of Set 6 | longyearbyen
# Processing Record 45 of Set 6 | pingzhuang
# Processing Record 46 of Set 6 | coahuayana
# Processing Record 47 of Set 6 | bara
# Processing Record 48 of Set 6 | villa constitucion
# Processing Record 49 of Set 6 | bambanglipuro
# Processing Record 50 of Set 6 | lasa
# Processing Record 1 of Set 7 | adrar
# Processing Record 2 of Set 7 | nigde
# Processing Record 3 of Set 7 | les cayes
# Processing Record 4 of Set 7 | risod
# Processing Record 5 of Set 7 | zenzeli
# Processing Record 6 of Set 7 | saldanha
# Processing Record 7 of Set 7 | inirida
# Processing Record 8 of Set 7 | tautira
# Processing Record 9 of Set 7 | lorengau
# Processing Record 10 of Set 7 | vieques
# Processing Record 11 of Set 7 | svetlaya
# Processing Record 12 of Set 7 | rumonge
# Processing Record 13 of Set 7 | syamzha
# Processing Record 14 of Set 7 | moose factory
# Processing Record 15 of Set 7 | dalbandin
# Processing Record 16 of Set 7 | muros
# Processing Record 17 of Set 7 | altamira
# Processing Record 18 of Set 7 | port lincoln
# Processing Record 19 of Set 7 | kardailovo
# Processing Record 20 of Set 7 | bethel
# Processing Record 21 of Set 7 | sibolga
# Processing Record 22 of Set 7 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 23 of Set 7 | guarapari
# Processing Record 24 of Set 7 | ibra
# Processing Record 25 of Set 7 | faya
# Processing Record 26 of Set 7 | egvekinot
# Processing Record 27 of Set 7 | korla
# Processing Record 28 of Set 7 | palmer
# Processing Record 29 of Set 7 | akureyri
# Processing Record 30 of Set 7 | kopavogur
# Processing Record 31 of Set 7 | buta
# Processing Record 32 of Set 7 | ouadda
# Processing Record 33 of Set 7 | provideniya
# Processing Record 34 of Set 7 | digapahandi
# Processing Record 35 of Set 7 | los llanos de aridane
# Processing Record 36 of Set 7 | quatre cocos
# Processing Record 37 of Set 7 | kahului
# Processing Record 38 of Set 7 | paamiut
# Processing Record 39 of Set 7 | along
# Processing Record 40 of Set 7 | sisimiut
# Processing Record 41 of Set 7 | college
# Processing Record 42 of Set 7 | allanridge
# Processing Record 43 of Set 7 | eyl
# Processing Record 44 of Set 7 | nanortalik
# Processing Record 45 of Set 7 | aripuana
# Processing Record 46 of Set 7 | skibbereen
# Processing Record 47 of Set 7 | humboldt
# Processing Record 48 of Set 7 | portland
# Processing Record 49 of Set 7 | lyngseidet
# Processing Record 50 of Set 7 | inderborskiy
# City not found. Skipping...
# Processing Record 1 of Set 8 | pontianak
# Processing Record 2 of Set 8 | xining
# Processing Record 3 of Set 8 | dawei
# Processing Record 4 of Set 8 | dalianwan
# Processing Record 5 of Set 8 | bichura
# Processing Record 6 of Set 8 | ojos de agua
# Processing Record 7 of Set 8 | kuching
# Processing Record 8 of Set 8 | ornskoldsvik
# Processing Record 9 of Set 8 | kuito
# Processing Record 10 of Set 8 | belyy yar
# Processing Record 11 of Set 8 | hinganghat
# Processing Record 12 of Set 8 | la rioja
# Processing Record 13 of Set 8 | flin flon
# Processing Record 14 of Set 8 | half moon bay
# Processing Record 15 of Set 8 | mitsamiouli
# Processing Record 16 of Set 8 | waipawa
# Processing Record 17 of Set 8 | kashi
# Processing Record 18 of Set 8 | biak
# Processing Record 19 of Set 8 | belmonte
# Processing Record 20 of Set 8 | la ronge
# Processing Record 21 of Set 8 | grindavik
# Processing Record 22 of Set 8 | opuwo
# Processing Record 23 of Set 8 | haines junction
# Processing Record 24 of Set 8 | tura
# Processing Record 25 of Set 8 | tuatapere
# Processing Record 26 of Set 8 | nouadhibou
# Processing Record 27 of Set 8 | vila franca do campo
# Processing Record 28 of Set 8 | ulaangom
# Processing Record 29 of Set 8 | vagur
# Processing Record 30 of Set 8 | ijaki
# City not found. Skipping...
# Processing Record 31 of Set 8 | nadym
# Processing Record 32 of Set 8 | payson
# Processing Record 33 of Set 8 | oshakati
# Processing Record 34 of Set 8 | natal
# Processing Record 35 of Set 8 | governador valadares
# Processing Record 36 of Set 8 | hervey bay
# Processing Record 37 of Set 8 | norden
# Processing Record 38 of Set 8 | annau
# Processing Record 39 of Set 8 | sesheke
# Processing Record 40 of Set 8 | cortez
# Processing Record 41 of Set 8 | nome
# Processing Record 42 of Set 8 | buraydah
# Processing Record 43 of Set 8 | armizonskoye
# Processing Record 44 of Set 8 | merauke
# Processing Record 45 of Set 8 | estelle
# Processing Record 46 of Set 8 | san carlos de bariloche
# Processing Record 47 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 48 of Set 8 | toamasina
# Processing Record 49 of Set 8 | camana
# Processing Record 50 of Set 8 | srednekolymsk
# Processing Record 1 of Set 9 | port hedland
# Processing Record 2 of Set 9 | palu
# Processing Record 3 of Set 9 | kirakira
# Processing Record 4 of Set 9 | hopelchen
# Processing Record 5 of Set 9 | salalah
# Processing Record 6 of Set 9 | le port
# Processing Record 7 of Set 9 | colomba
# Processing Record 8 of Set 9 | brus laguna
# Processing Record 9 of Set 9 | hella
# Processing Record 10 of Set 9 | kozhva
# Processing Record 11 of Set 9 | pemba
# Processing Record 12 of Set 9 | nguru
# Processing Record 13 of Set 9 | germantown
# Processing Record 14 of Set 9 | sayyan
# Processing Record 15 of Set 9 | alyangula
# Processing Record 16 of Set 9 | ahipara
# Processing Record 17 of Set 9 | jalu
# Processing Record 18 of Set 9 | margate
# Processing Record 19 of Set 9 | cockburn town
# Processing Record 20 of Set 9 | pochutla
# Processing Record 21 of Set 9 | siderno
# Processing Record 22 of Set 9 | panaba
# Processing Record 23 of Set 9 | kattivakkam
# Processing Record 24 of Set 9 | ilo
# Processing Record 25 of Set 9 | bintulu
# Processing Record 26 of Set 9 | aksu
# Processing Record 27 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 28 of Set 9 | taloqan
# Processing Record 29 of Set 9 | meridian
# Processing Record 30 of Set 9 | esperance
# Processing Record 31 of Set 9 | kabompo
# Processing Record 32 of Set 9 | pontes e lacerda
# Processing Record 33 of Set 9 | acapulco
# Processing Record 34 of Set 9 | sampit
# Processing Record 35 of Set 9 | novovorontsovka
# Processing Record 36 of Set 9 | dalvik
# Processing Record 37 of Set 9 | cayenne
# Processing Record 38 of Set 9 | vazante
# Processing Record 39 of Set 9 | san quintin
# Processing Record 40 of Set 9 | changji
# Processing Record 41 of Set 9 | akyab
# Processing Record 42 of Set 9 | viransehir
# Processing Record 43 of Set 9 | damoh
# Processing Record 44 of Set 9 | altay
# Processing Record 45 of Set 9 | tazovskiy
# Processing Record 46 of Set 9 | sergeyevka
# Processing Record 47 of Set 9 | chikoy
# City not found. Skipping...
# Processing Record 48 of Set 9 | bourail
# Processing Record 49 of Set 9 | grants
# Processing Record 50 of Set 9 | ahmadpur sial
# Processing Record 1 of Set 10 | rio grande
# Processing Record 2 of Set 10 | chicama
# Processing Record 3 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 10 | yarim
# Processing Record 5 of Set 10 | tilichiki
# Processing Record 6 of Set 10 | mount gambier
# Processing Record 7 of Set 10 | heze
# Processing Record 8 of Set 10 | harsin
# Processing Record 9 of Set 10 | sola
# Processing Record 10 of Set 10 | atbasar
# Processing Record 11 of Set 10 | sorland
# Processing Record 12 of Set 10 | rio gallegos
# Processing Record 13 of Set 10 | maltahohe
# Processing Record 14 of Set 10 | dwarka
# Processing Record 15 of Set 10 | umm lajj
# Processing Record 16 of Set 10 | hofn
# Processing Record 17 of Set 10 | kruglolesskoye
# Processing Record 18 of Set 10 | halifax
# Processing Record 19 of Set 10 | guanaja
# Processing Record 20 of Set 10 | xiamen
# Processing Record 21 of Set 10 | araouane
# Processing Record 22 of Set 10 | voi
# Processing Record 23 of Set 10 | tianpeng
# Processing Record 24 of Set 10 | jackson
# Processing Record 25 of Set 10 | kiama
# Processing Record 26 of Set 10 | sinkat
# City not found. Skipping...
# Processing Record 27 of Set 10 | zambezi
# Processing Record 28 of Set 10 | komsomolskiy
# Processing Record 29 of Set 10 | ishikari
# Processing Record 30 of Set 10 | odweyne
# Processing Record 31 of Set 10 | naryan-mar
# Processing Record 32 of Set 10 | les herbiers
# Processing Record 33 of Set 10 | east london
# Processing Record 34 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 35 of Set 10 | lithakia
# Processing Record 36 of Set 10 | kozlovka
# Processing Record 37 of Set 10 | tsiroanomandidy
# Processing Record 38 of Set 10 | harer
# Processing Record 39 of Set 10 | martinez
# Processing Record 40 of Set 10 | jurm
# Processing Record 41 of Set 10 | lompoc
# Processing Record 42 of Set 10 | bira
# Processing Record 43 of Set 10 | venezuela
# Processing Record 44 of Set 10 | kaili
# Processing Record 45 of Set 10 | nabire
# Processing Record 46 of Set 10 | douentza
# Processing Record 47 of Set 10 | kaabong
# Processing Record 48 of Set 10 | anjozorobe
# Processing Record 49 of Set 10 | hambantota
# Processing Record 50 of Set 10 | sorong
# Processing Record 1 of Set 11 | novoagansk
# Processing Record 2 of Set 11 | elat
# Processing Record 3 of Set 11 | astana
# Processing Record 4 of Set 11 | chateau-gontier
# Processing Record 5 of Set 11 | fallon
# Processing Record 6 of Set 11 | sao filipe
# Processing Record 7 of Set 11 | puerto leguizamo
# Processing Record 8 of Set 11 | vostok
# Processing Record 9 of Set 11 | hof
# Processing Record 10 of Set 11 | najran
# Processing Record 11 of Set 11 | ancud
# Processing Record 12 of Set 11 | port elizabeth
# Processing Record 13 of Set 11 | usinsk
# Processing Record 14 of Set 11 | pasni
# Processing Record 15 of Set 11 | izumo
# Processing Record 16 of Set 11 | vangaindrano
# Processing Record 17 of Set 11 | araripina
# Processing Record 18 of Set 11 | san rafael del sur
# Processing Record 19 of Set 11 | kidal
# Processing Record 20 of Set 11 | jaumave
# Processing Record 21 of Set 11 | castelo do piaui
# Processing Record 22 of Set 11 | gobabis
# Processing Record 23 of Set 11 | anadyr
# Processing Record 24 of Set 11 | lapao
# Processing Record 25 of Set 11 | kelvington
# Processing Record 26 of Set 11 | arawa
# Processing Record 27 of Set 11 | concarneau
# Processing Record 28 of Set 11 | sao gabriel da cachoeira
# Processing Record 29 of Set 11 | tanabe
# Processing Record 30 of Set 11 | albolote
# Processing Record 31 of Set 11 | tucuman
# Processing Record 32 of Set 11 | bemidji
# Processing Record 33 of Set 11 | sabang
# Processing Record 34 of Set 11 | raga
# Processing Record 35 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 36 of Set 11 | balabac
# Processing Record 37 of Set 11 | alaca
# Processing Record 38 of Set 11 | ambilobe
# Processing Record 39 of Set 11 | danville
# Processing Record 40 of Set 11 | otjiwarongo
# Processing Record 41 of Set 11 | wanning
# Processing Record 42 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 11 | togul
# Processing Record 44 of Set 11 | muisne
# Processing Record 45 of Set 11 | brawley
# Processing Record 46 of Set 11 | kushiro
# Processing Record 47 of Set 11 | magadi
# Processing Record 48 of Set 11 | klaksvik
# Processing Record 49 of Set 11 | presov
# Processing Record 50 of Set 11 | rahden
# Processing Record 1 of Set 12 | ostersund
# Processing Record 2 of Set 12 | ingham
# Processing Record 3 of Set 12 | atherton
# Processing Record 4 of Set 12 | taltal
# Processing Record 5 of Set 12 | nelson bay
# Processing Record 6 of Set 12 | fatehpur
# Processing Record 7 of Set 12 | mindelo
# Processing Record 8 of Set 12 | nevel
# Processing Record 9 of Set 12 | san jeronimo
# Processing Record 10 of Set 12 | damietta
# Processing Record 11 of Set 12 | boa vista
# Processing Record 12 of Set 12 | bartica
# Processing Record 13 of Set 12 | semaria
# Processing Record 14 of Set 12 | buchanan
# Processing Record 15 of Set 12 | celestun
# Processing Record 16 of Set 12 | itahari
# City not found. Skipping...
# Processing Record 17 of Set 12 | castle rock
# Processing Record 18 of Set 12 | henties bay
# Processing Record 19 of Set 12 | vanimo
# Processing Record 20 of Set 12 | brainerd
# Processing Record 21 of Set 12 | muravlenko
# Processing Record 22 of Set 12 | ondorhaan
# City not found. Skipping...
# Processing Record 23 of Set 12 | progreso
# Processing Record 24 of Set 12 | alta floresta
# Processing Record 25 of Set 12 | tukrah
# Processing Record 26 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 27 of Set 12 | verkhnyaya maksakovka
# Processing Record 28 of Set 12 | kalmunai
# Processing Record 29 of Set 12 | kota belud
# Processing Record 30 of Set 12 | tulum
# Processing Record 31 of Set 12 | gambela
# Processing Record 32 of Set 12 | shenzhen
# Processing Record 33 of Set 12 | botwood
# Processing Record 34 of Set 12 | ca mau
# Processing Record 35 of Set 12 | tena
# Processing Record 36 of Set 12 | kazachinskoye
# Processing Record 37 of Set 12 | amapa
# Processing Record 38 of Set 12 | chabahar
# Processing Record 39 of Set 12 | bonfim
# Processing Record 40 of Set 12 | honiara
# Processing Record 41 of Set 12 | ilulissat
# Processing Record 42 of Set 12 | la macarena
# Processing Record 43 of Set 12 | skjervoy
# Processing Record 44 of Set 12 | general roca
# Processing Record 45 of Set 12 | lensk
# Processing Record 46 of Set 12 | marienburg
# Processing Record 47 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 48 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 49 of Set 12 | three hills
# Processing Record 50 of Set 12 | lisakovsk
# Processing Record 1 of Set 13 | prado
# Processing Record 2 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 3 of Set 13 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 13 | severobaykalsk
# Processing Record 5 of Set 13 | iqaluit
# Processing Record 6 of Set 13 | sao jose da coroa grande
# Processing Record 7 of Set 13 | guaira
# Processing Record 8 of Set 13 | sterling
# Processing Record 9 of Set 13 | guarapuava
# Processing Record 10 of Set 13 | orlovskiy
# Processing Record 11 of Set 13 | carmelo
# Processing Record 12 of Set 13 | port-cartier
# Processing Record 13 of Set 13 | kendari
# Processing Record 14 of Set 13 | nassau
# Processing Record 15 of Set 13 | san isidro
# Processing Record 16 of Set 13 | wanxian
# Processing Record 17 of Set 13 | ust-kulom
# Processing Record 18 of Set 13 | iskateley
# Processing Record 19 of Set 13 | puerto maldonado
# Processing Record 20 of Set 13 | cabangahan
# Processing Record 21 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 22 of Set 13 | emba
# Processing Record 23 of Set 13 | marsa matruh
# Processing Record 24 of Set 13 | dengzhou
# Processing Record 25 of Set 13 | ust-maya
# Processing Record 26 of Set 13 | contamana
# Processing Record 27 of Set 13 | berbera
# Processing Record 28 of Set 13 | kroya
# Processing Record 29 of Set 13 | knysna
# Processing Record 30 of Set 13 | ubatuba
# Processing Record 31 of Set 13 | quang ngai
# Processing Record 32 of Set 13 | kamaishi
# Processing Record 33 of Set 13 | olenino
# Processing Record 34 of Set 13 | mogadishu
# Processing Record 35 of Set 13 | alihe
# Processing Record 36 of Set 13 | jasper
# Processing Record 37 of Set 13 | santa vitoria do palmar
# Processing Record 38 of Set 13 | oussouye
# Processing Record 39 of Set 13 | cap malheureux
# Processing Record 40 of Set 13 | noumea
# Processing Record 41 of Set 13 | grand gaube
# Processing Record 42 of Set 13 | onguday
# Processing Record 43 of Set 13 | saint anthony
# Processing Record 44 of Set 13 | chengde
# Processing Record 45 of Set 13 | tiznit
# Processing Record 46 of Set 13 | nampula
# Processing Record 47 of Set 13 | broken hill
# Processing Record 48 of Set 13 | theodoriana
# Processing Record 49 of Set 13 | novyy urengoy
# Processing Record 50 of Set 13 | kysyl-syr
# Processing Record 1 of Set 14 | shubarkuduk
# Processing Record 2 of Set 14 | mount vernon
# Processing Record 3 of Set 14 | bonthe
# Processing Record 4 of Set 14 | morondava
# Processing Record 5 of Set 14 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 14 | carauari
# Processing Record 7 of Set 14 | giulvaz
# Processing Record 8 of Set 14 | praia
# Processing Record 9 of Set 14 | montepuez
# Processing Record 10 of Set 14 | catuday
# Processing Record 11 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 14 | tiarei
# Processing Record 13 of Set 14 | kununurra
# Processing Record 14 of Set 14 | gambo
# Processing Record 15 of Set 14 | marsh harbour
# Processing Record 16 of Set 14 | comodoro rivadavia
# Processing Record 17 of Set 14 | isiro
# Processing Record 18 of Set 14 | howard springs
# Processing Record 19 of Set 14 | safaga
# Processing Record 20 of Set 14 | belen
# Processing Record 21 of Set 14 | innoshima
# Processing Record 22 of Set 14 | chimbote
# Processing Record 23 of Set 14 | thinadhoo
# Processing Record 24 of Set 14 | balikpapan
# Processing Record 25 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 26 of Set 14 | knin
# Processing Record 27 of Set 14 | axim
# Processing Record 28 of Set 14 | shangrao
# Processing Record 29 of Set 14 | lazaro cardenas
# Processing Record 30 of Set 14 | zadar
# Processing Record 31 of Set 14 | kefar shemaryahu
# Processing Record 32 of Set 14 | ulladulla
# Processing Record 33 of Set 14 | byron bay
# Processing Record 34 of Set 14 | rosarito
# Processing Record 35 of Set 14 | sikonge
# Processing Record 36 of Set 14 | kangaatsiaq
# Processing Record 37 of Set 14 | charters towers
# Processing Record 38 of Set 14 | manzhouli
# Processing Record 39 of Set 14 | svetlogorsk
# Processing Record 40 of Set 14 | karakendzha
# City not found. Skipping...
# Processing Record 41 of Set 14 | dakar
# Processing Record 42 of Set 14 | tecoanapa
# Processing Record 43 of Set 14 | boden
# Processing Record 44 of Set 14 | sivaki
# Processing Record 45 of Set 14 | mende
# Processing Record 46 of Set 14 | sangar
# Processing Record 47 of Set 14 | ratnagiri
# Processing Record 48 of Set 14 | dali
# Processing Record 49 of Set 14 | kirpilskaya
# Processing Record 50 of Set 14 | flinders
# Processing Record 1 of Set 15 | diapaga
# Processing Record 2 of Set 15 | kawalu
# Processing Record 3 of Set 15 | port augusta
# Processing Record 4 of Set 15 | nemuro
# Processing Record 5 of Set 15 | bolgatanga
# Processing Record 6 of Set 15 | simpelveld
# Processing Record 7 of Set 15 | takayama
# Processing Record 8 of Set 15 | lac du bonnet
# Processing Record 9 of Set 15 | beloha
# Processing Record 10 of Set 15 | qasigiannguit
# Processing Record 11 of Set 15 | eydhafushi
# Processing Record 12 of Set 15 | disna
# Processing Record 13 of Set 15 | aljezur
# Processing Record 14 of Set 15 | constitucion
# Processing Record 15 of Set 15 | edendale
# Processing Record 16 of Set 15 | kudahuvadhoo
# Processing Record 17 of Set 15 | khovu-aksy
# Processing Record 18 of Set 15 | talnakh
# Processing Record 19 of Set 15 | shellbrook
# Processing Record 20 of Set 15 | ligayan
# Processing Record 21 of Set 15 | nova olimpia
# Processing Record 22 of Set 15 | ji-parana
# City not found. Skipping...
# Processing Record 23 of Set 15 | cairns
# Processing Record 24 of Set 15 | susangerd
# Processing Record 25 of Set 15 | nova olinda do norte
# Processing Record 26 of Set 15 | coralici
# Processing Record 27 of Set 15 | ponta delgada
# Processing Record 28 of Set 15 | kizema
# Processing Record 29 of Set 15 | finschhafen
# Processing Record 30 of Set 15 | kot kapura
# Processing Record 31 of Set 15 | tabatinga
# Processing Record 32 of Set 15 | sambava
# Processing Record 33 of Set 15 | swan hill
# Processing Record 34 of Set 15 | marrakesh
# Processing Record 35 of Set 15 | el alto
# Processing Record 36 of Set 15 | san vicente
# Processing Record 37 of Set 15 | dundee
# Processing Record 38 of Set 15 | salinas
# Processing Record 39 of Set 15 | raudeberg
# Processing Record 40 of Set 15 | tezu
# Processing Record 41 of Set 15 | lat yao
# Processing Record 42 of Set 15 | sumbe
# Processing Record 43 of Set 15 | birao
# Processing Record 44 of Set 15 | samarai
# Processing Record 45 of Set 15 | sulphur springs
# Processing Record 46 of Set 15 | felidhoo
# City not found. Skipping...
# Processing Record 47 of Set 15 | roma
# Processing Record 48 of Set 15 | bundaberg
# Processing Record 49 of Set 15 | ugoofaaru
# Processing Record 50 of Set 15 | ulundi
# Processing Record 1 of Set 16 | mitha tiwana
# Processing Record 2 of Set 16 | fort nelson
# Processing Record 3 of Set 16 | kupang
# Processing Record 4 of Set 16 | alexandria
# Processing Record 5 of Set 16 | kayes
# Processing Record 6 of Set 16 | shirgaon
# Processing Record 7 of Set 16 | izhma
# Processing Record 8 of Set 16 | gurskoye
# City not found. Skipping...
# Processing Record 9 of Set 16 | bonoua
# Processing Record 10 of Set 16 | asosa
# Processing Record 11 of Set 16 | namibe
# Processing Record 12 of Set 16 | bababe
# City not found. Skipping...
# Processing Record 13 of Set 16 | devils lake
# Processing Record 14 of Set 16 | verkhniy baskunchak
# Processing Record 15 of Set 16 | goleniow
# Processing Record 16 of Set 16 | ardistan
# City not found. Skipping...
# Processing Record 17 of Set 16 | rocha
# Processing Record 18 of Set 16 | colares
# Processing Record 19 of Set 16 | berlevag
# Processing Record 20 of Set 16 | boueni
# Processing Record 21 of Set 16 | erzin
# Processing Record 22 of Set 16 | bushehr
# Processing Record 23 of Set 16 | sokolo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 720

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Saint-Philippe -21.3585   55.7679     71.19        74          65
# 1           Aswan  24.0934   32.9070     85.39        13           0
# 2          Durres  41.3231   19.4414     62.78        78           1
# 3       Busselton -33.6500  115.3333     56.17        82          57
# 4          Kodiak  57.7900 -152.4072     54.91        71           0
# 5          Burnie -41.0667  145.9167     50.92        78          96
# 6         Beterou   9.1992    2.2586     74.53        88          98
# 7    San Patricio  28.0170  -97.5169     86.54        61           1
# 8         Mataura -46.1927  168.8643     51.48        62         100
# 9           Cabra  37.4725   -4.4421     57.29        85          76
#
#    Wind Speed Country Current Description                 Date
# 0       13.98      RE          light rain  2022-05-30 00:20:39
# 1       10.25      EG           clear sky  2022-05-30 00:20:39
# 2        5.37      AL           clear sky  2022-05-30 00:20:39
# 3        5.26      AU       broken clouds  2022-05-30 00:20:40
# 4        6.91      US           clear sky  2022-05-30 00:20:40
# 5        3.06      AU     overcast clouds  2022-05-30 00:20:40
# 6        1.81      BJ          light rain  2022-05-30 00:20:41
# 7       22.30      US           clear sky  2022-05-30 00:20:41
# 8        4.79      NZ          light rain  2022-05-30 00:20:42
# 9        5.59      ES       broken clouds  2022-05-30 00:20:42

# %%
city_data_df2 = city_data_df.copy().drop(columns=["Date"])
city_data_df2.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Saint-Philippe -21.3585   55.7679     71.19        74          65
# 1           Aswan  24.0934   32.9070     85.39        13           0
# 2          Durres  41.3231   19.4414     62.78        78           1
# 3       Busselton -33.6500  115.3333     56.17        82          57
# 4          Kodiak  57.7900 -152.4072     54.91        71           0
# 5          Burnie -41.0667  145.9167     50.92        78          96
# 6         Beterou   9.1992    2.2586     74.53        88          98
# 7    San Patricio  28.0170  -97.5169     86.54        61           1
# 8         Mataura -46.1927  168.8643     51.48        62         100
# 9           Cabra  37.4725   -4.4421     57.29        85          76
#
#    Wind Speed Country Current Description
# 0       13.98      RE          light rain
# 1       10.25      EG           clear sky
# 2        5.37      AL           clear sky
# 3        5.26      AU       broken clouds
# 4        6.91      US           clear sky
# 5        3.06      AU     overcast clouds
# 6        1.81      BJ          light rain
# 7       22.30      US           clear sky
# 8        4.79      NZ          light rain
# 9        5.59      ES       broken clouds

# %%
# Create the output file (csv).
output_data_file = "weather_Data/WeatherPy_Database.csv"

# Export the City_Data into a csv.
city_data_df2.to_csv(output_data_file, index_label="City_ID")
